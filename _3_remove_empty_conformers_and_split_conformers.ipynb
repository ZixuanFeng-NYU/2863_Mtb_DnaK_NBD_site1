# %%
import sys, os

# %%
List=os.listdir('sdf')
for i in List:
    if os.stat("sdf/%s"%i).st_size == 0:
        print(i)
        os.system("rm sdf/%s"%i)

# %%
mkdir -p ligand

# %%
os.system("python split_sdf.py sdf/%d.sdf ligand/%d"%(i,i))
